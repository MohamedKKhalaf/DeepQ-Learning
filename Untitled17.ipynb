# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedKKhalaf/DeepQ-Learning/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import gym
import numpy as np
import tensorflow as tf
from collections import deque
from keras.models import Sequential
from keras.layers import Dense

EPISODES = 100



class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse',
                      optimizer=tf.keras.optimizers.Adam(lr=self.learning_rate))
        return model

    def memorize(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                Q_next=self.model.predict(next_state)[0]
                target = (reward + self.gamma *np.amax(Q_next))

            target_f = self.model.predict(state)
            target_f[0][action] = target
            #train network
            self.model.fit(state, target_f, epochs=1, verbose=1)

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)


if __name__ == "__main__":
    env = gym.make('CartPole-v0')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n
    agent = DQNAgent(state_size, action_size)
    # agent.load("./save/cartpole-dqn.h5")
    done = False
    batch_size = 8

    for e in range(EPISODES):
        state = env.reset()
        state = np.reshape(state, [1, state_size])
        done = False
        for time in range(500):
            if e > (EPISODES*0.8):
                env.render()
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            reward = reward if not done else -10
            next_state = np.reshape(next_state, [1, state_size])
            agent.memorize(state, action, reward, next_state, done)
            state = next_state
            if done:
                print("episode: {}/{},score:{}, e: {:.2}"
                      .format(e, EPISODES,time, agent.epsilon))
                break
            if len(agent.memory) > batch_size:
                agent.replay(batch_size)
        # if e % 10 == 0:
        #     agent.save("./save/cartpole-dqn.h5")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1/1 [==============================] - 1s 1s/step - loss: 0.5762
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5353
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5069
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5067
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5195
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5298
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5194
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5265
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4982
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5006
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5247
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5233
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5454
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5484
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5631
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4650
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4934
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4889
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4848
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5684
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4519
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5631
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5676
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5433
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5440
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4411
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4573
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4482
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4442
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5837
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5882
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5682
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4259
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5809
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5964
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4320
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4343
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6002
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4995
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5903
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6035
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6079
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5936
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6129
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4082
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4029
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5879
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5038
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6077
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4126
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5918
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5988
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5974
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3900
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6045
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3929
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6374
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3824
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6198
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3939
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6171
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3913
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4999
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5861
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3713
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3704
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6496
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3783
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4894
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6805
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6287
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5929
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5907
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6949
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3488
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6242
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6934
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7240
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3392
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4616
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6840
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3423
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3439
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7414
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3262
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5816
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3381
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7349
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7442
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3050
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8242
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7730
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3099
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3182
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8830
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2895
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3080
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2814
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2813
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2671
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8372
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0173
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2710
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8895
# episode: 0/100,score:21, e: 1.0
# 1/1 [==============================] - 0s 15ms/step - loss: 0.9572
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0737
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2577
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2424
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7557
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8678
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9907
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3837
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4686
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2476
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2332
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0140
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3407
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2048
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1970
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7015
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0689
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4506
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2516
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9688
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9692
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9286
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4960
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3205
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1801
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9356
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7004
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9346
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1774
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8963
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1433
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5155
# 1/1 [==============================] - 0s 9ms/step - loss: 77.0561
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9278
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1588
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0750
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1409
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1175
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5334
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1806
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1873
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4840
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2414
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5473
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0528
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3642
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5643
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5778
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3838
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1506
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1421
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3727
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9071
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8309
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5351
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5981
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4117
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8350
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7994
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1728
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3887
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1947
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5545
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8998
# 1/1 [==============================] - 0s 5ms/step - loss: 1.
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4243
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5778
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5843
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6204
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9851
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5030
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2003
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4009
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0040
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5843
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5922
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4531
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5266
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8627
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5680
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0043
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7224
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5800
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4865
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0764
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3431
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4762
# 1/1 [==============================] - 0s 9ms/step - loss: 117.6482
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0012
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1756
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2910
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5130
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0126
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4910
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1732
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4423
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3573
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6654
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1994
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0574
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4540
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1319
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3946
# 1/1 [==============================] - 0s 6ms/step - loss: 5.1730
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3993
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4578
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3795
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3944
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0047
# 1/1 [==============================] - 0s 6ms/step - loss: 3.3813
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3309
# 1/1 [==============================] - 0s 6ms/step - loss: 5.5501
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0238
# 1/1 [==============================] - 0s 6ms/step - loss: 8.0669e-04
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6407
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1040
# 1/1 [==============================] - 0s 7ms/step - loss: 115.3929
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7594
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1336
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0903
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8401
# 1/1 [==============================] - 0s 5ms/step - loss: 2.8336
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0146
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1223
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0033
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6611
# 1/1 [==============================] - 0s 6ms/step - loss: 4.5563
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9133
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9064
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0076
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0909
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9371
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0471
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1985
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7188
# 1/1 [==============================] - 0s 7ms/step - loss: 111.6264
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0109
# 1/1 [==============================] - 0s 6ms/step - loss: 3.5702
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1255
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8176
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4858
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1265
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5232
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8456
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2780
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6811
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0117
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0195
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1607
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3137
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0152
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9629
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1705
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0924
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5595
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6848
# 1/1 [==============================] - 0s 5ms/step - loss: 3.1423
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9946
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1015
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1273
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1377
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7754
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3007
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7507
# episode: 2/100,score:22, e: 1.0
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1716
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5728
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8459
# 1/1 [==============================] - 0s 5ms/step - loss: 0.9417
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7457
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3382
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1612
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5519
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3509
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3276
# 1/1 [==============================] - 0s 6ms/step - loss: 175.7514
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1715
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7772
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6631
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1769
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6223
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1060
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8751
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7129
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1875
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0894
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0375
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0283
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2024
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0906
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0473
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1229
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1549
# 1/1 [==============================] - 0s 10ms/step - loss: 3.3688
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5899
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0880
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0419
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5544
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f74916c2c601> in <module>()
#      89                 break
#      90             if len(agent.memory) > batch_size:
# ---> 91                 agent.replay(batch_size)
#      92         # if e % 10 == 0:
#      93         #     agent.save("./save/cartpole-dqn.h5")
#
# <ipython-input-1-f74916c2c601> in replay(self, batch_size)
#      50                 target = (reward + self.gamma *np.amax(Q_next))
#      51
# ---> 52             target_f = self.model.predict(state)
#      53             target_f[0][action] = target
#      54             #train network
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1959           use_multiprocessing=use_multiprocessing,
#    1960           model=self,
# -> 1961           steps_per_execution=self._steps_per_execution)
#    1962
#    1963       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1397   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1398     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1399   return DataHandler(*args, **kwargs)
#    1400
#    1401
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1159         use_multiprocessing=use_multiprocessing,
#    1160         distribution_strategy=tf.distribute.get_strategy(),
# -> 1161         model=model)
#    1162
#    1163     strategy = tf.distribute.get_strategy()
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     326     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     327
# --> 328     dataset = self.slice_inputs(indices_dataset, inputs)
#     329
#     330     if shuffle == "batch":
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     359
#     360     dataset = dataset.map(
# --> 361         grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     362
#     363     # Default optimizations are disabled to avoid the overhead of (unnecessary)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2022           deterministic,
#    2023           preserve_cardinality=True,
# -> 2024           name=name)
#    2025
#    2026   def flat_map(self, map_func, name=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5236         self._transformation_name(),
#    5237         dataset=input_dataset,
# -> 5238         use_legacy_function=use_legacy_function)
#    5239     if deterministic is None:
#    5240       self._deterministic = "default"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     269         fn_factory = trace_tf_function(defun_kwargs)
#     270
# --> 271     self._function = fn_factory()
#     272     # There is no graph to add in eager mode.
#     273     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3069     """
#    3070     graph_function = self._get_concrete_function_garbage_collected(
# -> 3071         *args, **kwargs)
#    3072     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3073     return graph_function
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3034       args, kwargs = None, None
#    3035     with self._lock:
# -> 3036       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3037       seen_names = set()
#    3038       captured = object_identity.ObjectIdentitySet(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3290
#    3291           self._function_cache.add_call_context(cache_key.call_context)
# -> 3292           graph_function = self._create_graph_function(args, kwargs)
#    3293           self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                                    graph_function)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3138             arg_names=arg_names,
#    3139             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3140             capture_by_value=self._capture_by_value),
#    3141         self._function_attributes,
#    3142         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1164       # TensorArrays and `None`s.
#    1165       func_outputs = nest.map_structure(convert, func_outputs,
# -> 1166                                         expand_composites=True)
#    1167
#    1168       check_mutation(func_args_before, func_args, original_func)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in convert(x)
#    1122               "ExtensionType.")
#    1123       if add_control_dependencies:
# -> 1124         x = deps_ctx.mark_as_return(x)
#    1125       return x
#    1126
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/auto_control_deps.py in mark_as_return(self, tensor)
#     248     # of a new identity operation that the stateful operations definitely don't
#     249     # depend on.
# --> 250     tensor = array_ops.identity(tensor)
#     251     self._returned_tensors.add(tensor)
#     252     return tensor
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py in identity(input, name)
#     285     # variables. Variables have correct handle data when graph building.
#     286     input = ops.convert_to_tensor(input)
# --> 287   ret = gen_array_ops.identity(input, name=name)
#     288   # Propagate handle data for happier shape inference for resource variables.
#     289   if hasattr(input, "_handle_data"):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_array_ops.py in identity(input, name)
#    4076   # Add nodes to the TensorFlow graph.
#    4077   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# -> 4078         "Identity", input=input, name=name)
#    4079   _result = _outputs[:]
#    4080   if _execute.must_record_gradient():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     719       elif arg.type_attr:
#     720         t = _AttrValue(attr_protos, arg.type_attr, op_type_name)
# --> 721         output_structure.append(None)
#     722       elif arg.type_list_attr:
#     723         t = _AttrValue(attr_protos, arg.type_list_attr, op_type_name)
#
# KeyboardInterrupt:
